# %%
1 % 1
# Out:
# 0

# %%
n = 16
a = [0, 1]
for i in range(n - 2):
    a.append(2* a[-1] + a[-2])
a
# Out:
# [0,
#  1,
#  2,
#  5,
#  12,
#  29,
#  70,
#  169,
#  408,
#  985,
#  2378,
#  5741,
#  13860,
#  33461,
#  80782,
#  195025]

# %%
b = [1, 5]
for i in range(n // 2 - 2):
    b.append(6* b[-1] - b[-2])
b
# Out:
# [1, 5, 29, 169, 985, 5741, 33461, 195025]

# %%
c = [5, 169]
for i in range(n//4 -2):
    c.append(34* c[-1] - c[-2])
c
# Out:
# [5, 169, 5741, 195025]

# %%
c = [5, 169]
for i in range(n//4 -2):
    c.append(34* c[-1] - c[-2])
c

# %%
c = [5, 169]
r = 1
for i in range(10):
    c.append(r* c[-1] - r * c[-1]**2)
c
# Out:
# [5,
#  169,
#  -28392,
#  -806134056,
#  -649852117049145192,
#  -422307774033255903775410294945862056,
#  -178343856008923529392609390326460259892257545112717826522874251926409192,
#  -31806530976131649282094222522080806874537818846499124900278926479053756916500377273071223687065378998241262701404620657633037154138626948502056,
#  -,
#  -...,
#  -...,
#  -...]
